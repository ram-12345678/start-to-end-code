# %% [markdown]
# <a href="https://colab.research.google.com/github/ram-12345678/start-to-end-code/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install git+https://github.com/huggingface/transformers.git sentencepiece
# !pip install torchaudio scipy
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-5v13ux1a
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-5v13ux1a
#   Resolved https://github.com/huggingface/transformers.git to commit 2b9e252b16396c926dad0e3c31802b4af8004e93
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.42.0.dev0-py3-none-any.whl size=9131386 sha256=dcf546b8d1e74fb446879b6ab73741c13b6c619091a9ba26d2c28941f5913f58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a721aln5/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ...

# %%
# Import necessary libraries
from transformers import AutoProcessor, SeamlessM4Tv2Model
import torchaudio
import scipy.io.wavfile as wavfile
from IPython.display import Audio

# Initialize processor and model
processor = AutoProcessor.from_pretrained("facebook/seamless-m4t-v2-large")
model = SeamlessM4Tv2Model.from_pretrained("facebook/seamless-m4t-v2-large")

# Generate speech from text
text_inputs = processor(text="Hello, my dog is cute", src_lang="eng", return_tensors="pt")
audio_array_from_text = model.generate(**text_inputs, tgt_lang="rus")[0].cpu().numpy().squeeze()

# Load and process audio file
audio, orig_freq = torchaudio.load("https://www2.cs.uic.edu/~i101/SoundFiles/preamble10.wav")
audio = torchaudio.functional.resample(audio, orig_freq=orig_freq, new_freq=16000)
audio_inputs = processor(audios=audio, return_tensors="pt")
audio_array_from_audio = model.generate(**audio_inputs, tgt_lang="rus")[0].cpu().numpy().squeeze()

# Listen to the audio samples
sample_rate = model.config.sampling_rate
display(Audio(audio_array_from_text, rate=sample_rate))
# Uncomment the next line to listen to the translated audio from the uploaded audio file
# display(Audio(audio_array_from_audio, rate=sample_rate))

# Save the generated audio as WAV files
wavfile.write("out_from_text.wav", rate=sample_rate, data=audio_array_from_text)
wavfile.write("out_from_audio.wav", rate=sample_rate, data=audio_array_from_audio)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:24: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.7k [00:00<?, ?B/s]
# ...

# %%
# Install dependencies
# !pip install git+https://github.com/huggingface/transformers.git sentencepiece
# !pip install torchaudio scipy
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-5_j7z7o1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-5_j7z7o1
#   Resolved https://github.com/huggingface/transformers.git to commit 2b9e252b16396c926dad0e3c31802b4af8004e93
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.42.0.dev0-py3-none-any.whl size=9131386 sha256=4075868a4cdfc5b78c89d6d2219f5311cde2175368f67d76559209e77760c549
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l0qvwel_/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ...

# %%
# !pip install git+https://github.com/huggingface/transformers.git sentencepiece
# !pip install torchaudio scipy ipywidgets
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-pog0b4jq
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-pog0b4jq
#   Resolved https://github.com/huggingface/transformers.git to commit 2b9e252b16396c926dad0e3c31802b4af8004e93
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.0 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
from transformers import AutoProcessor, SeamlessM4Tv2Model
import torchaudio
import scipy.io.wavfile as wavfile
from IPython.display import Audio, display
import ipywidgets as widgets
import os

# Retrieve your Hugging Face token from Colab secrets
hf_token = "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"  # Replace this with your actual token

# Initialize processor and model with the token
processor = AutoProcessor.from_pretrained("facebook/seamless-m4t-v2-large", use_auth_token=hf_token)
model = SeamlessM4Tv2Model.from_pretrained("facebook/seamless-m4t-v2-large", use_auth_token=hf_token)

# Language dictionary for selection
lang_dict = {
    'English': 'eng',
    'Russian': 'rus',
    'Spanish': 'spa',
    # Add more languages as needed
}

# Widgets for source and target language selection
source_lang_widget = widgets.Dropdown(options=lang_dict.keys(), description='Source Language:')
target_lang_widget = widgets.Dropdown(options=lang_dict.keys(), description='Target Language:')
input_text_widget = widgets.Textarea(description='Input Text:', placeholder='Enter text to translate...')
output_text_widget = widgets.Output()

# Display widgets
display(source_lang_widget)
display(target_lang_widget)
display(input_text_widget)
display(output_text_widget)

def translate_text(change):
    source_lang = lang_dict[source_lang_widget.value]
    target_lang = lang_dict[target_lang_widget.value]
    input_text = input_text_widget.value

    text_inputs = processor(text=input_text, src_lang=source_lang, return_tensors="pt")
    audio_array_from_text = model.generate(**text_inputs, tgt_lang=target_lang)[0].cpu().numpy().squeeze()

    with output_text_widget:
        output_text_widget.clear_output()
        display(Audio(audio_array_from_text, rate=model.config.sampling_rate))
        # Save the audio file
        wavfile.write("translated_text_audio.wav", rate=model.config.sampling_rate, data=audio_array_from_text)
        print("Audio saved as 'translated_text_audio.wav'")

input_text_widget.observe(translate_text, names='value')

# To handle audio input as well, you can add similar widgets and logic
audio_file_widget = widgets.FileUpload(description="Upload Audio File")
output_audio_widget = widgets.Output()

# Display audio upload widget
display(audio_file_widget)
display(output_audio_widget)

def translate_audio(change):
    if audio_file_widget.value:
        source_lang = lang_dict[source_lang_widget.value]
        target_lang = lang_dict[target_lang_widget.value]

        # Load uploaded audio file
        audio_info = next(iter(audio_file_widget.value.values()))
        audio_file = audio_info['content']
        with open('uploaded_audio.wav', 'wb') as f:
            f.write(audio_file)

        # Process and translate audio file
        audio, orig_freq = torchaudio.load('uploaded_audio.wav')
        audio = torchaudio.functional.resample(audio, orig_freq=orig_freq, new_freq=16000)
        audio_inputs = processor(audios=audio, return_tensors="pt")
        audio_array_from_audio = model.generate(**audio_inputs, tgt_lang=target_lang)[0].cpu().numpy().squeeze()

        with output_audio_widget:
            output_audio_widget.clear_output()
            display(Audio(audio_array_from_audio, rate=model.config.sampling_rate))
            # Save the audio file
            wavfile.write("translated_audio.wav", rate=model.config.sampling_rate, data=audio_array_from_audio)
            print("Audio saved as 'translated_audio.wav'")

audio_file_widget.observe(translate_audio, names='value')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio saved as 'translated_text_audio.wav'

# %%
# Import necessary libraries
from transformers import AutoProcessor, SeamlessM4Tv2Model
import torchaudio
import scipy.io.wavfile as wavfile
from IPython.display import Audio, display
import ipywidgets as widgets
import os

# Retrieve your Hugging Face token from Colab secrets
hf_token = "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"  # Replace this with your actual token

# Initialize processor and model with the token
processor = AutoProcessor.from_pretrained("facebook/seamless-m4t-v2-large", use_auth_token=hf_token)
model = SeamlessM4Tv2Model.from_pretrained("facebook/seamless-m4t-v2-large", use_auth_token=hf_token)

# Language dictionary for selection
lang_dict = {
    'English': 'eng',
    'Russian': 'rus',
    'Spanish': 'spa',
    # Add more languages as needed
}

# Widgets for source and target language selection
source_lang_widget = widgets.Dropdown(options=lang_dict.keys(), description='Source Language:')
target_lang_widget = widgets.Dropdown(options=lang_dict.keys(), description='Target Language:')
input_text_widget = widgets.Textarea(description='Input Text:', placeholder='Enter text to translate...')
output_text_widget = widgets.Output()

# Display widgets
display(source_lang_widget)
display(target_lang_widget)
display(input_text_widget)
display(output_text_widget)

def translate_text(change):
    source_lang = lang_dict[source_lang_widget.value]
    target_lang = lang_dict[target_lang_widget.value]
    input_text = input_text_widget.value

    text_inputs = processor(text=input_text, src_lang=source_lang, return_tensors="pt")
    audio_array_from_text = model.generate(**text_inputs, tgt_lang=target_lang)[0].cpu().numpy().squeeze()

    with output_text_widget:
        output_text_widget.clear_output()
        display(Audio(audio_array_from_text, rate=model.config.sampling_rate))
        # Save the audio file
        wavfile.write("translated_text_audio.wav", rate=model.config.sampling_rate, data=audio_array_from_text)
        print("Audio saved as 'translated_text_audio.wav'")

input_text_widget.observe(translate_text, names='value')

# Widgets for audio input
audio_file_widget = widgets.FileUpload(description="Upload Audio File")
output_audio_widget = widgets.Output()

# Display audio upload widget
display(audio_file_widget)
display(output_audio_widget)

def translate_audio(change):
    if audio_file_widget.value:
        source_lang = lang_dict[source_lang_widget.value]
        target_lang = lang_dict[target_lang_widget.value]

        # Load uploaded audio file
        audio_info = next(iter(audio_file_widget.value.values()))
        audio_file = audio_info['content']
        with open('/content/MovaviVideoConverterSetupC_Wnpm1x5_.exe', 'wb') as f:
            f.write(audio_file)

        # Process and translate audio file
        audio, orig_freq = torchaudio.load('uploaded_audio.wav')
        audio = torchaudio.functional.resample(audio, orig_freq=orig_freq, new_freq=16000)
        audio_inputs = processor(audios=audio, return_tensors="pt")
        audio_array_from_audio = model.generate(**audio_inputs, tgt_lang=target_lang)[0].cpu().numpy().squeeze()

        with output_audio_widget:
            output_audio_widget.clear_output()
            display(Audio(audio_array_from_audio, rate=model.config.sampling_rate))
            # Save the audio file
            wavfile.write("translated_audio.wav", rate=model.config.sampling_rate, data=audio_array_from_audio)
            print("Audio saved as 'translated_audio.wav'")

audio_file_widget.observe(translate_audio, names='value')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:24: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/processing_auto.py:219: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...
